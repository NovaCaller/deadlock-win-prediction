# %%
# parquet dateien einlesen
import pandas as pd

df_info_general = pd.read_parquet("../filtered_data/match_info_general.parquet")
df_info_timestamp = pd.read_parquet("../filtered_data/match_info_timestamp.parquet")
df_player_general = pd.read_parquet("../filtered_data/match_player_general.parquet")
df_player_timestamp = pd.read_parquet("../filtered_data/match_player_timestamp.parquet")

# %% [markdown]
# match_info_general.parquet

# %%
df_info_general.head()

# %%
df_info_general.info()

# %%
df_info_general.describe(include="all")

# %% [markdown]
# match_info_timestamp.parquet

# %%
df_info_timestamp.head()

# %%
df_info_timestamp.info()

# %%
df_info_timestamp.describe(include="all")

# %% [markdown]
# match_player_general.parquet

# %%
df_player_general.head()

# %%
df_player_general.info()

# %%
df_player_general.describe(include="all")

# %% [markdown]
# match_player_timestamp.parquet

# %%
df_player_timestamp.head()

# %%
df_player_timestamp.info()

# %%
df_player_timestamp.describe(include="all")
